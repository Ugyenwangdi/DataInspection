# %% [markdown]
# # Exploring Data using pandas

# %% [markdown]
# ## 1. Loading Data

# %%
import pandas as pd
df = pd.read_csv("imdb1.csv")

# %% [markdown]
# ## 2. Understanding data

# %%
df.head()
# Out:
#    Unnamed: 0                     title  \
# 0           0  The Shawshank Redemption
# 1           1           The Dark Knight
# 2           2                 Inception
# 3           3                Fight Club
# 4           4              Forrest Gump
#
#                                   genres  runtime  rating      votes     gross
# 0                      Drama              142 min     9.3  2,557,442   $28.34M
# 1       Action| Crime| Drama              152 min     9.1  2,515,739  $534.86M
# 2  Action| Adventure| Sci-Fi              148 min     8.8  2,245,966  $292.58M
# 3                      Drama              139 min     8.8  2,013,415   $37.03M
# 4             Drama| Romance              142 min     8.8  1,973,705  $330.25M

# %%
df.tail()
# Out:
#     Unnamed: 0                                       title  \
# 45          45  Star Wars: Episode VI - Return of the Jedi
# 46          46                                  Braveheart
# 47          47                                Finding Nemo
# 48          48                                          Up
# 49          49                              Reservoir Dogs
#
#                                       genres  runtime  rating      votes  \
# 45    Action| Adventure| Fantasy              131 min     8.3  1,012,709
# 46     Biography| Drama| History              178 min     8.4  1,010,028
# 47  Animation| Adventure| Comedy              100 min     8.2  1,008,792
# 48  Animation| Adventure| Comedy               96 min     8.3  1,004,503
# 49        Crime| Drama| Thriller               99 min     8.3    982,508
#
#        gross
# 45  $309.13M
# 46   $75.60M
# 47  $380.84M
# 48  $293.00M
# 49    $2.83M

# %%
df.shape
# Out:
# (50, 7)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'genres', 'runtime', 'rating', 'votes', 'gross'], dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# title          object
# genres         object
# runtime        object
# rating        float64
# votes          object
# gross          object
# dtype: object

# %%
df.count()
# Out:
# Unnamed: 0    50
# title         50
# genres        48
# runtime       50
# rating        48
# votes         49
# gross         49
# dtype: int64

# %% [markdown]
# ## 3. Summarising and computing descriptive statistics

# %% [markdown]
# Calling DataFrame’s sum method returns a Series containing column sums. Passing axis=1 sums over the rows instead.

# %%
df.sum()
# Out:
# Unnamed: 0                                                 1225
# title         The Shawshank RedemptionThe Dark KnightIncepti...
# genres        Drama            Action| Crime| Drama         ...
# runtime       142 min152 min148 min139 min142 min154 min136 ...
# rating                                                    426.5
# votes         2,557,4422,515,7392,245,9662,013,4151,973,7051...
# gross         $28.34M$534.86M$292.58M$37.03M$330.25M$107.93M...
# dtype: object

# %%
df.sum(axis = 1)
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_2448/1830824671.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum(axis = 1)
# 0      9.3
# 1     10.1
# 2     10.8
# 3     11.8
# 4     12.8
# 5     13.9
# 6     14.7
# 7     15.9
# 8     17.0
# 9     18.2
# 10    18.4
# 11    19.8
# 12    20.6
# 13    21.5
# 14    22.5
# 15    23.3
# 16    24.3
# 17    25.6
# 18    26.1
# 19    27.6
# 20    28.6
# 21    30.0
# 22    30.5
# 23    31.5
# 24    32.6
# 25    33.2
# 26    34.7
# 27    36.0
# 28    36.5
# 29    36.9
# 30    38.6
# 31    39.4
# 32    39.9
# 33    41.6
# 34    42.7
# 35    43.2
# 36    44.5
# 37    45.2
# 38    46.4
# 39    47.1
# 40    48.6
# 41    49.5
# 42    50.2
# 43    50.9
# 44    52.5
# 45    53.3
# 46    54.4
# 47    55.2
# 48    56.3
# 49    57.3
# dtype: float64

# %%
df.mean()
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_2448/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Unnamed: 0    24.50
# rating         8.53
# dtype: float64

# %%
df.mean(axis = 1)
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_2448/3216275966.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 1)
# 0      4.65
# 1      5.05
# 2      5.40
# 3      5.90
# 4      6.40
# 5      6.95
# 6      7.35
# 7      7.95
# 8      8.50
# 9      9.10
# 10     9.20
# 11     9.90
# 12    10.30
# 13    13.00
# 14    11.25
# 15    11.65
# 16    12.15
# 17    12.80
# 18    13.05
# 19    13.80
# 20    20.00
# 21    15.00
# 22    15.25
# 23    15.75
# 24    16.30
# 25    16.60
# 26    17.35
# 27    18.00
# 28    18.25
# 29    18.45
# 30    19.30
# 31    19.70
# 32    19.95
# 33    20.80
# 34    21.35
# 35    21.60
# 36    22.25
# 37    22.60
# 38    23.20
# 39    23.55
# 40    24.30
# 41    24.75
# 42    25.10
# 43    25.45
# 44    26.25
# 45    26.65
# 46    27.20
# 47    27.60
# 48    28.15
# 49    28.65
# dtype: float64

# %%
df.describe()
# Out:
#        Unnamed: 0     rating
# count    50.00000  48.000000
# mean     24.50000   8.529167
# std      14.57738   0.331315
# min       0.00000   7.900000
# 25%      12.25000   8.300000
# 50%      24.50000   8.500000
# 75%      36.75000   8.725000
# max      49.00000   9.300000

# %%
df['genres'].describe()
# Out:
# count                                         48
# unique                                        24
# top       Action| Adventure| Fantasy
# freq                                           5
# Name: genres, dtype: object

# %% [markdown]
# ## 4. Looking for missing data
#
# - pandas uses the floating point value NaN (Not a Number) to represent missing data in
# both floating as well as in non-floating point arrays.
#
# - The built-in Python None value is also treated as NA in object arrays:
#
# ![image.png](attachment:image.png)

# %%
df.isnull()
# Out:
# Unnamed: 0    0
# title         0
# genres        2
# runtime       0
# rating        2
# votes         1
# gross         1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# title         0
# genres        2
# runtime       0
# rating        2
# votes         1
# gross         1
# dtype: int64

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# title         0
# genres        2
# runtime       0
# rating        2
# votes         1
# gross         1
# dtype: int64

# %% [markdown]
# ## 5. Handling Missing Value (Numerical)

# %% [markdown]
# ### 5.1 Droping missing values
#
# DataFrame.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
#dropna() drops any row containing missing values. 
newdf = df.dropna()

# %%
newdf.shape
# Out:
# (44, 7)

# %%
filtered_df = df[df.notnull()]
filtered_df.shape
# Out:
# (50, 7)

# %%
newdf1 = df.dropna(axis = 1)
newdf1.head()
# Out:
#    Unnamed: 0                     title  runtime
# 0           0  The Shawshank Redemption  142 min
# 1           1           The Dark Knight  152 min
# 2           2                 Inception  148 min
# 3           3                Fight Club  139 min
# 4           4              Forrest Gump  142 min

# %% [markdown]
# ### 5.2 Filling Missing value
#
# Rather than filtering out missing data (and potentially discarding other data along with
# it), you may want to fill in the “holes” in any number of ways. For most purposes, the
# fillna method is the workhorse function to use. Calling fillna with a constant replaces
# missing values with that value:
#
# DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None)

# %%
#using fillna() without any paramters
df.fillna(0)
# Out:
#     Unnamed: 0                                              title  \
# 0            0                           The Shawshank Redemption
# 1            1                                    The Dark Knight
# 2            2                                          Inception
# 3            3                                         Fight Club
# 4            4                                       Forrest Gump
# 5            5                                       Pulp Fiction
# 6            6                                         The Matrix
# 7            7  The Lord of the Rings: The Fellowship of the Ring
# 8            8      The Lord of the Rings: The Return of the King
# 9            9                                      The Godfather
# 10          10                              The Dark Knight Rises
# 11          11              The Lord of the Rings: The Two Towers
# 12          12                                              Se7en
# 13          13                                   Django Unchained
# 14          14                                          Gladiator
# 15          15                                      Batman Begins
# 16          16                               Inglourious Basterds
# 17          17                           The Silence of the Lambs
# 18          18                                       The Avengers
# 19          19                                Saving Private Ryan
# 20          20                                          Star Wars
# 21          21                                   Schindler's List
# 22          22                                       The Prestige
# 23          23                                       The Departed
# 24          24                                     The Green Mile
# 25          25                                     Shutter Island
# 26          26                            The Empire Strikes Back
# 27          27                             The Godfather: Part II
# 28          28                                            Memento
# 29          29                                             Avatar
# 30          30                                 Back to the Future
# 31          31                                    American Beauty
# 32          32                                            Titanic
# 33          33                                               Léon
# 34          34                                         Goodfellas
# 35          35                                     V for Vendetta
# 36          36                                 American History X
# 37          37                                  Kill Bill: Vol. 1
# 38          38                                             WALL·E
# 39          39  Pirates of the Caribbean: The Curse of the Bla...
# 40          40                         Terminator 2: Judgment Day
# 41          41                                 The Usual Suspects
# 42          42                                    The Truman Show
# 43          43                                           Iron Man
# 44          44                                      The Lion King
# 45          45         Star Wars: Episode VI - Return of the Jedi
# 46          46                                         Braveheart
# 47          47                                       Finding Nemo
# 48          48                                                 Up
# 49          49                                     Reservoir Dogs
#
#                                       genres  runtime  rating      votes  \
# 0                          Drama              142 min     9.3  2,557,442
# 1           Action| Crime| Drama              152 min     9.1  2,515,739
# 2      Action| Adventure| Sci-Fi              148 min     8.8  2,245,966
# 3                          Drama              139 min     8.8  2,013,415
# 4                 Drama| Romance              142 min     8.8  1,973,705
# 5                   Crime| Drama              154 min     8.9  1,965,482
# 6                 Action| Sci-Fi              136 min     8.7  1,843,346
# 7       Action| Adventure| Drama              178 min     8.9  1,783,703
# 8       Action| Adventure| Drama              201 min     9.0  1,761,777
# 9                                          0  175 min     9.2  1,760,572
# 10          Action| Crime| Drama              164 min     8.4  1,629,444
# 11      Action| Adventure| Drama              179 min     8.8  1,591,702
# 12         Crime| Drama| Mystery              127 min     8.6  1,568,610
# 13                Drama| Western              165 min     0.0  1,478,353
# 14      Action| Adventure| Drama              155 min     8.5  1,441,008
# 15          Action| Crime| Drama              140 min     8.3          0
# 16         Adventure| Drama| War              153 min     8.3  1,379,464
# 17                                         0  118 min     8.6  1,372,721
# 18     Action| Adventure| Sci-Fi              143 min     8.1  1,343,264
# 19                    Drama| War              169 min     8.6  1,333,567
# 20    Action| Adventure| Fantasy              121 min     0.0  1,310,503
# 21     Biography| Drama| History              195 min     9.0  1,304,473
# 22      Drama| Mystery| Thriller              130 min     8.5  1,282,398
# 23        Crime| Drama| Thriller              151 min     8.5  1,274,835
# 24         Crime| Drama| Fantasy              189 min     8.6  1,244,014
# 25             Mystery| Thriller              138 min     8.2  1,243,207
# 26    Action| Adventure| Fantasy              124 min     8.7  1,239,035
# 27                  Crime| Drama              202 min     9.0  1,219,448
# 28             Mystery| Thriller              113 min     8.5  1,198,063
# 29    Action| Adventure| Fantasy              162 min     7.9  1,183,340
# 30     Adventure| Comedy| Sci-Fi              116 min     8.6  1,148,883
# 31                         Drama              122 min     8.4  1,125,302
# 32                Drama| Romance              194 min     7.9  1,124,413
# 33          Action| Crime| Drama              110 min     8.6  1,116,210
# 34       Biography| Crime| Drama              146 min     8.7  1,104,707
# 35         Action| Drama| Sci-Fi              132 min     8.2  1,091,528
# 36                         Drama              119 min     8.5  1,089,284
# 37          Action| Crime| Drama              111 min     8.2  1,074,792
# 38  Animation| Adventure| Family               98 min     8.4  1,073,518
# 39    Action| Adventure| Fantasy              143 min     8.1  1,066,939
# 40                Action| Sci-Fi              137 min     8.6  1,059,759
# 41         Crime| Drama| Mystery              106 min     8.5  1,053,410
# 42                 Comedy| Drama              103 min     8.2  1,023,856
# 43     Action| Adventure| Sci-Fi              126 min     7.9  1,016,926
# 44   Animation| Adventure| Drama               88 min     8.5  1,014,129
# 45    Action| Adventure| Fantasy              131 min     8.3  1,012,709
# 46     Biography| Drama| History              178 min     8.4  1,010,028
# 47  Animation| Adventure| Comedy              100 min     8.2  1,008,792
# 48  Animation| Adventure| Comedy               96 min     8.3  1,004,503
# 49        Crime| Drama| Thriller               99 min     8.3    982,508
#
#        gross
# 0    $28.34M
# 1   $534.86M
# 2   $292.58M
# 3    $37.03M
# 4   $330.25M
# 5   $107.93M
# 6   $171.48M
# 7   $315.54M
# 8   $377.85M
# 9   $134.97M
# 10         0
# 11  $342.55M
# 12  $100.13M
# 13  $162.81M
# 14  $187.71M
# 15  $206.85M
# 16  $120.54M
# 17  $130.74M
# 18  $623.28M
# 19  $216.54M
# 20  $322.74M
# 21   $96.90M
# 22   $53.09M
# 23  $132.38M
# 24  $136.80M
# 25  $128.01M
# 26  $290.48M
# 27   $57.30M
# 28   $25.54M
# 29  $760.51M
# 30  $210.61M
# 31  $130.10M
# 32  $659.33M
# 33   $19.50M
# 34   $46.84M
# 35   $70.51M
# 36    $6.72M
# 37   $70.10M
# 38  $223.81M
# 39  $305.41M
# 40  $204.84M
# 41   $23.34M
# 42  $125.62M
# 43  $318.41M
# 44  $422.78M
# 45  $309.13M
# 46   $75.60M
# 47  $380.84M
# 48  $293.00M
# 49    $2.83M

# %%
#Calling fillna with a dict you can use a different fill value for each column
df.fillna({"genres":'Comedy','rating':9.1,'votes':300000,'gross':'$200.00M'})[:5]
# Out:
#    Unnamed: 0                     title  \
# 0           0  The Shawshank Redemption
# 1           1           The Dark Knight
# 2           2                 Inception
# 3           3                Fight Club
# 4           4              Forrest Gump
#
#                                   genres  runtime  rating      votes     gross
# 0                      Drama              142 min     9.3  2,557,442   $28.34M
# 1       Action| Crime| Drama              152 min     9.1  2,515,739  $534.86M
# 2  Action| Adventure| Sci-Fi              148 min     8.8  2,245,966  $292.58M
# 3                      Drama              139 min     8.8  2,013,415   $37.03M
# 4             Drama| Romance              142 min     8.8  1,973,705  $330.25M

# %%
#using bfill() and fillna(method = 'bfill')
df.fillna(method='bfill')
df.bfill()[:5]
# Out:
#    Unnamed: 0                     title  \
# 0           0  The Shawshank Redemption
# 1           1           The Dark Knight
# 2           2                 Inception
# 3           3                Fight Club
# 4           4              Forrest Gump
#
#                                   genres  runtime  rating      votes     gross
# 0                      Drama              142 min     9.3  2,557,442   $28.34M
# 1       Action| Crime| Drama              152 min     9.1  2,515,739  $534.86M
# 2  Action| Adventure| Sci-Fi              148 min     8.8  2,245,966  $292.58M
# 3                      Drama              139 min     8.8  2,013,415   $37.03M
# 4             Drama| Romance              142 min     8.8  1,973,705  $330.25M

# %%
#using ffill() and fillna(method='ffill')
df.fillna(method = 'ffill')
df.ffill()[:5]
# Out:
#    Unnamed: 0                     title  \
# 0           0  The Shawshank Redemption
# 1           1           The Dark Knight
# 2           2                 Inception
# 3           3                Fight Club
# 4           4              Forrest Gump
#
#                                   genres  runtime  rating      votes     gross
# 0                      Drama              142 min     9.3  2,557,442   $28.34M
# 1       Action| Crime| Drama              152 min     9.1  2,515,739  $534.86M
# 2  Action| Adventure| Sci-Fi              148 min     8.8  2,245,966  $292.58M
# 3                      Drama              139 min     8.8  2,013,415   $37.03M
# 4             Drama| Romance              142 min     8.8  1,973,705  $330.25M

# %%
df.fillna({'genres':'Empty','rating':df['rating'].mean()})
# Out:
#     Unnamed: 0                                              title  \
# 0            0                           The Shawshank Redemption
# 1            1                                    The Dark Knight
# 2            2                                          Inception
# 3            3                                         Fight Club
# 4            4                                       Forrest Gump
# 5            5                                       Pulp Fiction
# 6            6                                         The Matrix
# 7            7  The Lord of the Rings: The Fellowship of the Ring
# 8            8      The Lord of the Rings: The Return of the King
# 9            9                                      The Godfather
# 10          10                              The Dark Knight Rises
# 11          11              The Lord of the Rings: The Two Towers
# 12          12                                              Se7en
# 13          13                                   Django Unchained
# 14          14                                          Gladiator
# 15          15                                      Batman Begins
# 16          16                               Inglourious Basterds
# 17          17                           The Silence of the Lambs
# 18          18                                       The Avengers
# 19          19                                Saving Private Ryan
# 20          20                                          Star Wars
# 21          21                                   Schindler's List
# 22          22                                       The Prestige
# 23          23                                       The Departed
# 24          24                                     The Green Mile
# 25          25                                     Shutter Island
# 26          26                            The Empire Strikes Back
# 27          27                             The Godfather: Part II
# 28          28                                            Memento
# 29          29                                             Avatar
# 30          30                                 Back to the Future
# 31          31                                    American Beauty
# 32          32                                            Titanic
# 33          33                                               Léon
# 34          34                                         Goodfellas
# 35          35                                     V for Vendetta
# 36          36                                 American History X
# 37          37                                  Kill Bill: Vol. 1
# 38          38                                             WALL·E
# 39          39  Pirates of the Caribbean: The Curse of the Bla...
# 40          40                         Terminator 2: Judgment Day
# 41          41                                 The Usual Suspects
# 42          42                                    The Truman Show
# 43          43                                           Iron Man
# 44          44                                      The Lion King
# 45          45         Star Wars: Episode VI - Return of the Jedi
# 46          46                                         Braveheart
# 47          47                                       Finding Nemo
# 48          48                                                 Up
# 49          49                                     Reservoir Dogs
#
#                                       genres  runtime    rating      votes  \
# 0                          Drama              142 min  9.300000  2,557,442
# 1           Action| Crime| Drama              152 min  9.100000  2,515,739
# 2      Action| Adventure| Sci-Fi              148 min  8.800000  2,245,966
# 3                          Drama              139 min  8.800000  2,013,415
# 4                 Drama| Romance              142 min  8.800000  1,973,705
# 5                   Crime| Drama              154 min  8.900000  1,965,482
# 6                 Action| Sci-Fi              136 min  8.700000  1,843,346
# 7       Action| Adventure| Drama              178 min  8.900000  1,783,703
# 8       Action| Adventure| Drama              201 min  9.000000  1,761,777
# 9                                      Empty  175 min  9.200000  1,760,572
# 10          Action| Crime| Drama              164 min  8.400000  1,629,444
# 11      Action| Adventure| Drama              179 min  8.800000  1,591,702
# 12         Crime| Drama| Mystery              127 min  8.600000  1,568,610
# 13                Drama| Western              165 min  8.529167  1,478,353
# 14      Action| Adventure| Drama              155 min  8.500000  1,441,008
# 15          Action| Crime| Drama              140 min  8.300000        NaN
# 16         Adventure| Drama| War              153 min  8.300000  1,379,464
# 17                                     Empty  118 min  8.600000  1,372,721
# 18     Action| Adventure| Sci-Fi              143 min  8.100000  1,343,264
# 19                    Drama| War              169 min  8.600000  1,333,567
# 20    Action| Adventure| Fantasy              121 min  8.529167  1,310,503
# 21     Biography| Drama| History              195 min  9.000000  1,304,473
# 22      Drama| Mystery| Thriller              130 min  8.500000  1,282,398
# 23        Crime| Drama| Thriller              151 min  8.500000  1,274,835
# 24         Crime| Drama| Fantasy              189 min  8.600000  1,244,014
# 25             Mystery| Thriller              138 min  8.200000  1,243,207
# 26    Action| Adventure| Fantasy              124 min  8.700000  1,239,035
# 27                  Crime| Drama              202 min  9.000000  1,219,448
# 28             Mystery| Thriller              113 min  8.500000  1,198,063
# 29    Action| Adventure| Fantasy              162 min  7.900000  1,183,340
# 30     Adventure| Comedy| Sci-Fi              116 min  8.600000  1,148,883
# 31                         Drama              122 min  8.400000  1,125,302
# 32                Drama| Romance              194 min  7.900000  1,124,413
# 33          Action| Crime| Drama              110 min  8.600000  1,116,210
# 34       Biography| Crime| Drama              146 min  8.700000  1,104,707
# 35         Action| Drama| Sci-Fi              132 min  8.200000  1,091,528
# 36                         Drama              119 min  8.500000  1,089,284
# 37          Action| Crime| Drama              111 min  8.200000  1,074,792
# 38  Animation| Adventure| Family               98 min  8.400000  1,073,518
# 39    Action| Adventure| Fantasy              143 min  8.100000  1,066,939
# 40                Action| Sci-Fi              137 min  8.600000  1,059,759
# 41         Crime| Drama| Mystery              106 min  8.500000  1,053,410
# 42                 Comedy| Drama              103 min  8.200000  1,023,856
# 43     Action| Adventure| Sci-Fi              126 min  7.900000  1,016,926
# 44   Animation| Adventure| Drama               88 min  8.500000  1,014,129
# 45    Action| Adventure| Fantasy              131 min  8.300000  1,012,709
# 46     Biography| Drama| History              178 min  8.400000  1,010,028
# 47  Animation| Adventure| Comedy              100 min  8.200000  1,008,792
# 48  Animation| Adventure| Comedy               96 min  8.300000  1,004,503
# 49        Crime| Drama| Thriller               99 min  8.300000    982,508
#
#        gross
# 0    $28.34M
# 1   $534.86M
# 2   $292.58M
# 3    $37.03M
# 4   $330.25M
# 5   $107.93M
# 6   $171.48M
# 7   $315.54M
# 8   $377.85M
# 9   $134.97M
# 10       NaN
# 11  $342.55M
# 12  $100.13M
# 13  $162.81M
# 14  $187.71M
# 15  $206.85M
# 16  $120.54M
# 17  $130.74M
# 18  $623.28M
# 19  $216.54M
# 20  $322.74M
# 21   $96.90M
# 22   $53.09M
# 23  $132.38M
# 24  $136.80M
# 25  $128.01M
# 26  $290.48M
# 27   $57.30M
# 28   $25.54M
# 29  $760.51M
# 30  $210.61M
# 31  $130.10M
# 32  $659.33M
# 33   $19.50M
# 34   $46.84M
# 35   $70.51M
# 36    $6.72M
# 37   $70.10M
# 38  $223.81M
# 39  $305.41M
# 40  $204.84M
# 41   $23.34M
# 42  $125.62M
# 43  $318.41M
# 44  $422.78M
# 45  $309.13M
# 46   $75.60M
# 47  $380.84M
# 48  $293.00M
# 49    $2.83M

# %%
#use interpolate()
df.interpolate()
# Out:
#     Unnamed: 0                                              title  \
# 0            0                           The Shawshank Redemption
# 1            1                                    The Dark Knight
# 2            2                                          Inception
# 3            3                                         Fight Club
# 4            4                                       Forrest Gump
# 5            5                                       Pulp Fiction
# 6            6                                         The Matrix
# 7            7  The Lord of the Rings: The Fellowship of the Ring
# 8            8      The Lord of the Rings: The Return of the King
# 9            9                                      The Godfather
# 10          10                              The Dark Knight Rises
# 11          11              The Lord of the Rings: The Two Towers
# 12          12                                              Se7en
# 13          13                                   Django Unchained
# 14          14                                          Gladiator
# 15          15                                      Batman Begins
# 16          16                               Inglourious Basterds
# 17          17                           The Silence of the Lambs
# 18          18                                       The Avengers
# 19          19                                Saving Private Ryan
# 20          20                                          Star Wars
# 21          21                                   Schindler's List
# 22          22                                       The Prestige
# 23          23                                       The Departed
# 24          24                                     The Green Mile
# 25          25                                     Shutter Island
# 26          26                            The Empire Strikes Back
# 27          27                             The Godfather: Part II
# 28          28                                            Memento
# 29          29                                             Avatar
# 30          30                                 Back to the Future
# 31          31                                    American Beauty
# 32          32                                            Titanic
# 33          33                                               Léon
# 34          34                                         Goodfellas
# 35          35                                     V for Vendetta
# 36          36                                 American History X
# 37          37                                  Kill Bill: Vol. 1
# 38          38                                             WALL·E
# 39          39  Pirates of the Caribbean: The Curse of the Bla...
# 40          40                         Terminator 2: Judgment Day
# 41          41                                 The Usual Suspects
# 42          42                                    The Truman Show
# 43          43                                           Iron Man
# 44          44                                      The Lion King
# 45          45         Star Wars: Episode VI - Return of the Jedi
# 46          46                                         Braveheart
# 47          47                                       Finding Nemo
# 48          48                                                 Up
# 49          49                                     Reservoir Dogs
#
#                                       genres  runtime  rating      votes  \
# 0                          Drama              142 min    9.30  2,557,442
# 1           Action| Crime| Drama              152 min    9.10  2,515,739
# 2      Action| Adventure| Sci-Fi              148 min    8.80  2,245,966
# 3                          Drama              139 min    8.80  2,013,415
# 4                 Drama| Romance              142 min    8.80  1,973,705
# 5                   Crime| Drama              154 min    8.90  1,965,482
# 6                 Action| Sci-Fi              136 min    8.70  1,843,346
# 7       Action| Adventure| Drama              178 min    8.90  1,783,703
# 8       Action| Adventure| Drama              201 min    9.00  1,761,777
# 9                                        NaN  175 min    9.20  1,760,572
# 10          Action| Crime| Drama              164 min    8.40  1,629,444
# 11      Action| Adventure| Drama              179 min    8.80  1,591,702
# 12         Crime| Drama| Mystery              127 min    8.60  1,568,610
# 13                Drama| Western              165 min    8.55  1,478,353
# 14      Action| Adventure| Drama              155 min    8.50  1,441,008
# 15          Action| Crime| Drama              140 min    8.30        NaN
# 16         Adventure| Drama| War              153 min    8.30  1,379,464
# 17                                       NaN  118 min    8.60  1,372,721
# 18     Action| Adventure| Sci-Fi              143 min    8.10  1,343,264
# 19                    Drama| War              169 min    8.60  1,333,567
# 20    Action| Adventure| Fantasy              121 min    8.80  1,310,503
# 21     Biography| Drama| History              195 min    9.00  1,304,473
# 22      Drama| Mystery| Thriller              130 min    8.50  1,282,398
# 23        Crime| Drama| Thriller              151 min    8.50  1,274,835
# 24         Crime| Drama| Fantasy              189 min    8.60  1,244,014
# 25             Mystery| Thriller              138 min    8.20  1,243,207
# 26    Action| Adventure| Fantasy              124 min    8.70  1,239,035
# 27                  Crime| Drama              202 min    9.00  1,219,448
# 28             Mystery| Thriller              113 min    8.50  1,198,063
# 29    Action| Adventure| Fantasy              162 min    7.90  1,183,340
# 30     Adventure| Comedy| Sci-Fi              116 min    8.60  1,148,883
# 31                         Drama              122 min    8.40  1,125,302
# 32                Drama| Romance              194 min    7.90  1,124,413
# 33          Action| Crime| Drama              110 min    8.60  1,116,210
# 34       Biography| Crime| Drama              146 min    8.70  1,104,707
# 35         Action| Drama| Sci-Fi              132 min    8.20  1,091,528
# 36                         Drama              119 min    8.50  1,089,284
# 37          Action| Crime| Drama              111 min    8.20  1,074,792
# 38  Animation| Adventure| Family               98 min    8.40  1,073,518
# 39    Action| Adventure| Fantasy              143 min    8.10  1,066,939
# 40                Action| Sci-Fi              137 min    8.60  1,059,759
# 41         Crime| Drama| Mystery              106 min    8.50  1,053,410
# 42                 Comedy| Drama              103 min    8.20  1,023,856
# 43     Action| Adventure| Sci-Fi              126 min    7.90  1,016,926
# 44   Animation| Adventure| Drama               88 min    8.50  1,014,129
# 45    Action| Adventure| Fantasy              131 min    8.30  1,012,709
# 46     Biography| Drama| History              178 min    8.40  1,010,028
# 47  Animation| Adventure| Comedy              100 min    8.20  1,008,792
# 48  Animation| Adventure| Comedy               96 min    8.30  1,004,503
# 49        Crime| Drama| Thriller               99 min    8.30    982,508
#
#        gross
# 0    $28.34M
# 1   $534.86M
# 2   $292.58M
# 3    $37.03M
# 4   $330.25M
# 5   $107.93M
# 6   $171.48M
# 7   $315.54M
# 8   $377.85M
# 9   $134.97M
# 10       NaN
# 11  $342.55M
# 12  $100.13M
# 13  $162.81M
# 14  $187.71M
# 15  $206.85M
# 16  $120.54M
# 17  $130.74M
# 18  $623.28M
# 19  $216.54M
# 20  $322.74M
# 21   $96.90M
# 22   $53.09M
# 23  $132.38M
# 24  $136.80M
# 25  $128.01M
# 26  $290.48M
# 27   $57.30M
# 28   $25.54M
# 29  $760.51M
# 30  $210.61M
# 31  $130.10M
# 32  $659.33M
# 33   $19.50M
# 34   $46.84M
# 35   $70.51M
# 36    $6.72M
# 37   $70.10M
# 38  $223.81M
# 39  $305.41M
# 40  $204.84M
# 41   $23.34M
# 42  $125.62M
# 43  $318.41M
# 44  $422.78M
# 45  $309.13M
# 46   $75.60M
# 47  $380.84M
# 48  $293.00M
# 49    $2.83M

# %% [markdown]
# ## 6 Handling missing values(Categorical)

# %% [markdown]
# #### 6.1 Deleting values

# %% [markdown]
# #### 6.2 Replacing with mode

# %% [markdown]
# #### 6.3 Predicting values

# %% [markdown]
# ## HomeWork/TODO - Data Inspection and Handling Missing Values
#
# Inspect yelp dataset and clean missing values using different techniques. Provide detailed documentation.
